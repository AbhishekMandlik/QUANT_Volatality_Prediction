# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from scipy.stats import probplot

# %%
import pandas as pd
import yfinance as yf

def get_top_nse_stocks(n=20):
    """
    Function to retrieve the top N stocks by market capitalization on the NSE.
    
    Args:
    - n: Number of top stocks to retrieve (default is 20).
    
    Returns:
    - List of dictionaries containing stock ticker symbol and company name.
    """
    top_stocks = [
        {"symbol": "RELIANCE.NS", "company": "Reliance Industries Limited"},
        {"symbol": "TCS.NS", "company": "Tata Consultancy Services Limited"},
        {"symbol": "HDFCBANK.NS", "company": "HDFC Bank Limited"},
        {"symbol": "HINDUNILVR.NS", "company": "Hindustan Unilever Limited"},
        {"symbol": "ICICIBANK.NS", "company": "ICICI Bank Limited"},
        {"symbol": "INFY.NS", "company": "Infosys Limited"},
        {"symbol": "KOTAKBANK.NS", "company": "Kotak Mahindra Bank Limited"},
        {"symbol": "ITC.NS", "company": "ITC Limited"},
        {"symbol": "BAJFINANCE.NS", "company": "Bajaj Finance Limited"},
        {"symbol": "AXISBANK.NS", "company": "Axis Bank Limited"},
        {"symbol": "BHARTIARTL.NS", "company": "Bharti Airtel Limited"},
        {"symbol": "WIPRO.NS", "company": "Wipro Limited"},
        {"symbol": "SBIN.NS", "company": "State Bank of India"},
        {"symbol": "DMART.NS", "company": "Avenue Supermarts Limited"},
        {"symbol": "ASIANPAINT.NS", "company": "Asian Paints Limited"},
        {"symbol": "ULTRACEMCO.NS", "company": "UltraTech Cement Limited"},
        {"symbol": "MARUTI.NS", "company": "Maruti Suzuki India Limited"},
        {"symbol": "LT.NS", "company": "Larsen & Toubro Limited"},
        {"symbol": "NESTLEIND.NS", "company": "Nestlé India Limited"},
        {"symbol": "SUNPHARMA.NS", "company": "Sun Pharmaceutical Industries Limited"}
    ]
    
    return top_stocks[:n]
def fetch_stock_data(symbol, start_date, end_date):
    """
    Function to fetch historical daily stock price data for a given symbol.
    
    Args:
    - symbol: Stock ticker symbol (e.g., 'AAPL' for Apple Inc.).
    - start_date: Start date of the historical data (YYYY-MM-DD).
    - end_date: End date of the historical data (YYYY-MM-DD).
    
    Returns:
    - Pandas DataFrame containing the historical stock price data.
    """
    stock_data = yf.download(symbol, start=start_date, end=end_date)
    return stock_data

def preprocess_stock_data(stock_data):
    """
    Function to preprocess the fetched stock data.
    
    Args:
    - stock_data: Pandas DataFrame containing the historical stock price data.
    
    Returns:
    - Preprocessed stock data with adjusted close prices.
    """
    # Drop rows with missing values
    stock_data.dropna(inplace=True)
    
    # Adjust for stock splits and dividends, if necessary
    # You may need additional preprocessing steps depending on the data source
    
    return stock_data

# Main code
if __name__ == "__main__":
    # Define the date range for historical data
    start_date = "2018-08-01"
    end_date = "2023-08-01"
    
    # Get the top N stocks by market capitalization on the NSE
    top_stocks = get_top_nse_stocks(n=20)
    
    # Fetch and preprocess data for each stock
    for stock_symbol in top_stocks:
        print(f"Fetching data for {stock_symbol}...")
        stock_data = fetch_stock_data(stock_symbol, start_date, end_date)
        preprocessed_data = preprocess_stock_data(stock_data)
        
        # Perform further analysis or save the preprocessed data as needed
# Out:
# Fetching data for {'symbol': 'RELIANCE.NS', 'company': 'Reliance Industries Limited'}...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17396/1102845149.py in <module>
#      81     for stock_symbol in top_stocks:
#      82         print(f"Fetching data for {stock_symbol}...")
# ---> 83         stock_data = fetch_stock_data(stock_symbol, start_date, end_date)
#      84         preprocessed_data = preprocess_stock_data(stock_data)
#      85
#
# ~\AppData\Local\Temp/ipykernel_17396/1102845149.py in fetch_stock_data(symbol, start_date, end_date)
#      48     - Pandas DataFrame containing the historical stock price data.
#      49     """
# ---> 50     stock_data = yf.download(symbol, start=start_date, end=end_date)
#      51     return stock_data
#      52
#
# ~\anaconda3\lib\site-packages\yfinance\utils.py in wrapper(*args, **kwargs)
#     101
# ...

# %%
preprocessed_data
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2018-08-01   570.000000   576.799988   563.799988   574.650024   542.403137
# 2018-08-02   575.900024   587.549988   575.299988   580.400024   547.830627
# 2018-08-03   583.900024   589.400024   583.849976   585.849976   552.974670
# 2018-08-06   586.500000   593.400024   575.099976   576.150024   543.819031
# 2018-08-07   580.450012   582.500000   568.250000   569.700012   537.730957
# ...                 ...          ...          ...          ...          ...
# 2023-07-25  1110.000000  1110.000000  1090.800049  1095.050049  1085.005615
# 2023-07-26  1097.050049  1114.400024  1094.099976  1112.000000  1101.800171
# 2023-07-27  1128.000000  1155.349976  1116.300049  1134.949951  1124.539551
# 2023-07-28  1129.949951  1143.900024  1121.650024  1138.550049  1132.096558
# 2023-07-31  1140.000000  1145.000000  1127.000000  1143.400024  1136.919067
#
#              Volume
# Date
# 2018-08-01  3672172
# ...

# %%
import pandas as pd
import yfinance as yf

def get_top_nse_stocks(n=20):
    """
    Function to retrieve the top N stocks by market capitalization on the NSE.
    
    Args:
    - n: Number of top stocks to retrieve (default is 20).
    
    Returns:
    - List of dictionaries containing stock ticker symbol and company name.
    """
    top_stocks = [
        {"symbol": "RELIANCE.NS", "company": "Reliance Industries Limited"},
        {"symbol": "TCS.NS", "company": "Tata Consultancy Services Limited"},
        {"symbol": "HDFCBANK.NS", "company": "HDFC Bank Limited"},
        {"symbol": "HINDUNILVR.NS", "company": "Hindustan Unilever Limited"},
        {"symbol": "ICICIBANK.NS", "company": "ICICI Bank Limited"},
        {"symbol": "INFY.NS", "company": "Infosys Limited"},
        {"symbol": "KOTAKBANK.NS", "company": "Kotak Mahindra Bank Limited"},
        {"symbol": "ITC.NS", "company": "ITC Limited"},
        {"symbol": "BAJFINANCE.NS", "company": "Bajaj Finance Limited"},
        {"symbol": "AXISBANK.NS", "company": "Axis Bank Limited"},
        {"symbol": "BHARTIARTL.NS", "company": "Bharti Airtel Limited"},
        {"symbol": "WIPRO.NS", "company": "Wipro Limited"},
        {"symbol": "SBIN.NS", "company": "State Bank of India"},
        {"symbol": "DMART.NS", "company": "Avenue Supermarts Limited"},
        {"symbol": "ASIANPAINT.NS", "company": "Asian Paints Limited"},
        {"symbol": "ULTRACEMCO.NS", "company": "UltraTech Cement Limited"},
        {"symbol": "MARUTI.NS", "company": "Maruti Suzuki India Limited"},
        {"symbol": "LT.NS", "company": "Larsen & Toubro Limited"},
        {"symbol": "NESTLEIND.NS", "company": "Nestlé India Limited"},
        {"symbol": "SUNPHARMA.NS", "company": "Sun Pharmaceutical Industries Limited"}
    ]
    
    return top_stocks[:n]

def fetch_stock_data(symbol, start_date, end_date):
    """
    Function to fetch historical daily stock price data for a given symbol.
    
    Args:
    - symbol: Stock ticker symbol (e.g., 'AAPL' for Apple Inc.).
    - start_date: Start date of the historical data (YYYY-MM-DD).
    - end_date: End date of the historical data (YYYY-MM-DD).
    
    Returns:
    - Pandas DataFrame containing the historical stock price data.
    """
    stock_data = yf.download(symbol, start=start_date, end=end_date)
    stock_data['Symbol'] = symbol  # Add a column for the stock symbol
    return stock_data

def preprocess_stock_data(stock_data):
    """
    Function to preprocess the fetched stock data.
    
    Args:
    - stock_data: Pandas DataFrame containing the historical stock price data.
    
    Returns:
    - Preprocessed stock data with adjusted close prices.
    """
    # Drop rows with missing values
    stock_data.dropna(inplace=True)
    
    # Adjust for stock splits and dividends, if necessary
    # You may need additional preprocessing steps depending on the data source
    
    return stock_data

# Main code
if __name__ == "__main__":
    # Define the date range for historical data
    start_date = "2018-08-01"
    end_date = "2023-08-01"
    
    # Get the top N stocks by market capitalization on the NSE
    top_stocks = get_top_nse_stocks(n=20)
    
    # Fetch and preprocess data for each stock
    for stock_info in top_stocks:
        stock_symbol = stock_info['symbol']
        print(f"Fetching data for {stock_symbol}...")
        stock_data = fetch_stock_data(stock_symbol, start_date, end_date)
        preprocessed_data = preprocess_stock_data(stock_data)
        
        # Perform further analysis or save the preprocessed data as needed
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Fetching data for RELIANCE.NS...
# Fetching data for TCS.NS...
# Fetching data for HDFCBANK.NS...
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Fetching data for HINDUNILVR.NS...
# Fetching data for ICICIBANK.NS...
# Fetching data for INFY.NS...
# Fetching data for KOTAKBANK.NS...
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Fetching data for ITC.NS...
# ...

# %%
preprocessed_data
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2018-08-01   570.000000   576.799988   563.799988   574.650024   542.403137
# 2018-08-02   575.900024   587.549988   575.299988   580.400024   547.830627
# 2018-08-03   583.900024   589.400024   583.849976   585.849976   552.974670
# 2018-08-06   586.500000   593.400024   575.099976   576.150024   543.819031
# 2018-08-07   580.450012   582.500000   568.250000   569.700012   537.730957
# ...                 ...          ...          ...          ...          ...
# 2023-07-25  1110.000000  1110.000000  1090.800049  1095.050049  1085.005615
# 2023-07-26  1097.050049  1114.400024  1094.099976  1112.000000  1101.800171
# 2023-07-27  1128.000000  1155.349976  1116.300049  1134.949951  1124.539551
# 2023-07-28  1129.949951  1143.900024  1121.650024  1138.550049  1132.096558
# 2023-07-31  1140.000000  1145.000000  1127.000000  1143.400024  1136.919067
#
#              Volume        Symbol
# Date
# ...

# %%
import pandas as pd
import yfinance as yf

def get_top_nse_stocks(n=20):
    """
    Function to retrieve the top N stocks by market capitalization on the NSE.
    
    Args:
    - n: Number of top stocks to retrieve (default is 20).
    
    Returns:
    - List of dictionaries containing stock ticker symbol and company name.
    """
    top_stocks = [
        {"symbol": "RELIANCE.NS", "company": "Reliance Industries Limited"},
        {"symbol": "TCS.NS", "company": "Tata Consultancy Services Limited"},
        {"symbol": "HDFCBANK.NS", "company": "HDFC Bank Limited"},
        {"symbol": "HINDUNILVR.NS", "company": "Hindustan Unilever Limited"},
        {"symbol": "ICICIBANK.NS", "company": "ICICI Bank Limited"},
        {"symbol": "INFY.NS", "company": "Infosys Limited"},
        {"symbol": "KOTAKBANK.NS", "company": "Kotak Mahindra Bank Limited"},
        {"symbol": "ITC.NS", "company": "ITC Limited"},
        {"symbol": "BAJFINANCE.NS", "company": "Bajaj Finance Limited"},
        {"symbol": "AXISBANK.NS", "company": "Axis Bank Limited"},
        {"symbol": "BHARTIARTL.NS", "company": "Bharti Airtel Limited"},
        {"symbol": "WIPRO.NS", "company": "Wipro Limited"},
        {"symbol": "SBIN.NS", "company": "State Bank of India"},
        {"symbol": "DMART.NS", "company": "Avenue Supermarts Limited"},
        {"symbol": "ASIANPAINT.NS", "company": "Asian Paints Limited"},
        {"symbol": "ULTRACEMCO.NS", "company": "UltraTech Cement Limited"},
        {"symbol": "MARUTI.NS", "company": "Maruti Suzuki India Limited"},
        {"symbol": "LT.NS", "company": "Larsen & Toubro Limited"},
        {"symbol": "NESTLEIND.NS", "company": "Nestlé India Limited"},
        {"symbol": "SUNPHARMA.NS", "company": "Sun Pharmaceutical Industries Limited"}
    ]
    
    return top_stocks[:n]

def fetch_stock_data(symbol, start_date, end_date):
    """
    Function to fetch historical daily stock price data for a given symbol.
    
    Args:
    - symbol: Stock ticker symbol (e.g., 'AAPL' for Apple Inc.).
    - start_date: Start date of the historical data (YYYY-MM-DD).
    - end_date: End date of the historical data (YYYY-MM-DD).
    
    Returns:
    - Pandas DataFrame containing the historical stock price data.
    """
    stock_data = yf.download(symbol, start=start_date, end=end_date)
    stock_data['Symbol'] = symbol  # Add a column for the stock symbol
    return stock_data

def preprocess_stock_data(stock_data):
    """
    Function to preprocess the fetched stock data.
    
    Args:
    - stock_data: Pandas DataFrame containing the historical stock price data.
    
    Returns:
    - Preprocessed stock data with adjusted close prices.
    """
    # Drop rows with missing values
    stock_data.dropna(inplace=True)
    
    # Adjust for stock splits and dividends, if necessary
    # You may need additional preprocessing steps depending on the data source
    
    return stock_data

# Main code
if __name__ == "__main__":
    # Define the date range for historical data
    start_date = "2018-08-01"
    end_date = "2023-08-01"
    
    # Get the top N stocks by market capitalization on the NSE
    top_stocks = get_top_nse_stocks(n=20)
    
    # List to store preprocessed data for all stocks
    all_stock_data = []
    
    # Fetch and preprocess data for each stock
    for stock_info in top_stocks:
        stock_symbol = stock_info['symbol']
        print(f"Fetching data for {stock_symbol}...")
        stock_data = fetch_stock_data(stock_symbol, start_date, end_date)
        preprocessed_data = preprocess_stock_data(stock_data)
        
        # Append preprocessed data to the list
        all_stock_data.append(preprocessed_data)
    
    # Combine preprocessed data for all stocks into one DataFrame
    combined_data = pd.concat(all_stock_data)
    
    # Save combined data to a CSV file
    combined_data.to_csv('combined_stock_data.csv')
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Fetching data for RELIANCE.NS...
# Fetching data for TCS.NS...
# Fetching data for HDFCBANK.NS...
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Fetching data for HINDUNILVR.NS...
# Fetching data for ICICIBANK.NS...
# Fetching data for INFY.NS...
# Fetching data for KOTAKBANK.NS...
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Fetching data for ITC.NS...
# Fetching data for BAJFINANCE.NS...
# Fetching data for AXISBANK.NS...
# ...

# %%
combined_data
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2018-08-01  1088.421631  1099.850830  1083.849976  1090.204590  1068.286377
# 2018-08-02  1089.427490  1089.427490  1066.066284  1068.260620  1046.783569
# 2018-08-03  1074.340942  1082.112793  1069.357788  1076.123901  1054.488892
# 2018-08-06  1075.895264  1093.541870  1074.661011  1090.433228  1068.510376
# 2018-08-07  1092.536133  1098.479370  1076.169556  1082.752808  1060.984253
# ...                 ...          ...          ...          ...          ...
# 2023-07-25  1110.000000  1110.000000  1090.800049  1095.050049  1085.005615
# 2023-07-26  1097.050049  1114.400024  1094.099976  1112.000000  1101.800171
# 2023-07-27  1128.000000  1155.349976  1116.300049  1134.949951  1124.539551
# 2023-07-28  1129.949951  1143.900024  1121.650024  1138.550049  1132.096558
# 2023-07-31  1140.000000  1145.000000  1127.000000  1143.400024  1136.919067
#
#               Volume        Symbol
# Date
# ...

# %%
reliance_data = combined_data[combined_data['Symbol'] == 'RELIANCE.NS']

# %%
reliance_data
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2018-08-01  1088.421631  1099.850830  1083.849976  1090.204590  1068.286377
# 2018-08-02  1089.427490  1089.427490  1066.066284  1068.260620  1046.783569
# 2018-08-03  1074.340942  1082.112793  1069.357788  1076.123901  1054.488892
# 2018-08-06  1075.895264  1093.541870  1074.661011  1090.433228  1068.510376
# 2018-08-07  1092.536133  1098.479370  1076.169556  1082.752808  1060.984253
# ...                 ...          ...          ...          ...          ...
# 2023-07-25  2494.000000  2505.199951  2480.000000  2485.800049  2477.050049
# 2023-07-26  2485.000000  2547.000000  2485.000000  2526.199951  2517.307617
# 2023-07-27  2534.050049  2537.649902  2490.350098  2502.699951  2493.890381
# 2023-07-28  2512.050049  2542.850098  2500.550049  2527.850098  2518.952148
# 2023-07-31  2527.850098  2553.899902  2517.949951  2549.250000  2540.276611
#
#               Volume       Symbol
# Date
# ...

# %%
reliance_data['Date'] = pd.to_datetime(reliance_data['Date'])

# Plot the adjusted close price against time
plt.figure(figsize=(10, 6))
plt.plot(reliance_data['Date'], reliance_data['Adj Close'], color='blue', label='Adjusted Close Price')
plt.title('Adjusted Close Price of Reliance Industries Limited (RELIANCE.NS)')
plt.xlabel('Date')
plt.ylabel('Adjusted Close Price')
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf


reliance_data['Date'] = pd.to_datetime(reliance_data['Date'])

# Plotting autocorrelation
plt.figure(figsize=(10, 6))
plot_acf(reliance_data['Adj Close'], lags=50, alpha=0.05)
plt.title('Autocorrelation of Adjusted Close Price of Reliance Industries Limited (RELIANCE.NS)')
plt.xlabel('Lag')
plt.ylabel('Autocorrelation')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
reliance_data['Daily Return'] = reliance_data['Adj Close'].pct_change()

# Calculate the variance of daily returns
variance = reliance_data['Daily Return'].var()

print("Variance of Reliance Industries Limited (RELIANCE.NS):", variance)
# Out:
# Variance of Reliance Industries Limited (RELIANCE.NS): 0.0003926682241145393

# %%
reliance_data['Date'] = pd.to_datetime(reliance_data['Date'])

# Calculate daily returns
reliance_data['Daily Return'] = reliance_data['Adj Close'].pct_change()

# Calculate rolling variance of daily returns (window size = 30 days for example)
rolling_variance = reliance_data['Daily Return'].rolling(window=30).var()

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(reliance_data['Date'], rolling_variance, color='blue')
plt.title('Rolling Variance of Daily Returns for Reliance Industries Limited (RELIANCE.NS)')
plt.xlabel('Date')
plt.ylabel('Variance')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
reliance_data['Date'] = pd.to_datetime(reliance_data['Date'])

# Calculate daily returns
reliance_data['Daily Return'] = reliance_data['Adj Close'].pct_change()

# Calculate rolling variance of daily returns (window size = 30 days for example)
rolling_variance = reliance_data['Daily Return'].rolling(window=30).var()

# Plotting autocorrelation of rolling variance
plt.figure(figsize=(10, 6))
plot_acf(rolling_variance.dropna(), lags=50, alpha=0.05)
plt.title('Autocorrelation of Rolling Variance of Daily Returns for Reliance Industries Limited (RELIANCE.NS)')
plt.xlabel('Lag')
plt.ylabel('Autocorrelation')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
r_log=np.log(reliance_data['Adj Close']).diff().dropna()

# %% [raw]
# rlog

# %% [raw]
# r

# %%
r_log
# Out:
# 2       0.007334
# 3       0.013209
# 4      -0.007068
# 5       0.027897
# 6       0.000205
#           ...
# 1228   -0.000643
# 1229    0.016122
# 1230   -0.009346
# 1231    0.009999
# 1232    0.008430
# Name: Adj Close, Length: 1231, dtype: float64

# %%
plt.figure(figsize=(10, 6))
plot_acf(r_log.dropna(), lags=50, alpha=0.05)
plt.title('Autocorrelation of Logarithm of Adjusted Close Price for Reliance Industries Limited (RELIANCE.NS)')
plt.xlabel('Lag')
plt.ylabel('Autocorrelation')
plt.grid(True)
plt.tight_layout()
plt.show()

# Plotting residuals
plt.figure(figsize=(10, 6))
plt.plot(r_log)
plt.title('Logarithm of Adjusted Close Price for Reliance Industries Limited (RELIANCE.NS)')
plt.xlabel('Time')
plt.ylabel('Logarithm of Adjusted Close Price')
plt.grid(True)
plt.tight_layout()
plt.show()

# Plotting probability plot
plt.figure(figsize=(10, 6))
probplot(r_log, plot=plt)
plt.title('Probability Plot of Logarithm of Adjusted Close Price for Reliance Industries Limited (RELIANCE.NS)')
plt.grid(True)
plt.tight_layout()
plt.show()

# Plotting partial autocorrelation
plt.figure(figsize=(10, 6))
plot_pacf(r_log.dropna(), lags=50)
plt.title('Partial Autocorrelation of Logarithm of Adjusted Close Price for Reliance Industries Limited (RELIANCE.NS)')
plt.xlabel('Lag')
plt.ylabel('Partial Autocorrelation')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Calculate the mean of the natural logarithm of the adjusted close price
r_log_mean = r_log.mean()

# Calculate the squared differences
r_log_daily = (r_log - r_log_mean) ** 2

#autocorrelation
plt.figure(figsize=(10, 6))
plot_acf(r_log_daily.dropna(), lags=120, alpha=0.05)
plt.title('Autocorrelation of Squared Differences from Mean of Logarithm of Adjusted Close Price for Reliance Industries Limited (RELIANCE.NS)')
plt.xlabel('Lag')
plt.ylabel('Autocorrelation')
plt.grid(True)
plt.tight_layout()
plt.show()
# Plotting residuals
plt.figure(figsize=(10, 6))
plt.plot(r_log_daily)
plt.title('Squared Differences from Mean of Logarithm of Adjusted Close Price for Reliance Industries Limited (RELIANCE.NS)')
plt.xlabel('Time')
plt.ylabel('Squared Differences')
plt.grid(True)
plt.tight_layout()
plt.show()

# Plotting probability plot
plt.figure(figsize=(10, 6))
probplot(r_log_daily, plot=plt)
plt.title('Probability Plot of Squared Differences from Mean of Logarithm of Adjusted Close Price for Reliance Industries Limited (RELIANCE.NS)')
plt.grid(True)
plt.tight_layout()
plt.show()

# Plotting partial autocorrelation
plt.figure(figsize=(10, 6))
plot_pacf(r_log_daily.dropna(), lags=120)
plt.title('Partial Autocorrelation of Squared Differences from Mean of Logarithm of Adjusted Close Price for Reliance Industries Limited (RELIANCE.NS)')
plt.xlabel('Lag')
plt.ylabel('Partial Autocorrelation')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
from arch import arch_model

# %%
# Clip outliers
lower_bound = r_log_daily.quantile(0.05)
upper_bound = r_log_daily.quantile(0.95)
r_log_daily_clipped = r_log_daily.clip(lower=lower_bound, upper=upper_bound)

# Initialize variables to store best model parameters and criterion value
best_p = None
best_q = None
best_criterion = float('inf')  # Initialize with infinity

# Iterate through values of p and q
for p in range(1, 6):
    for q in range(1, 6):
        # Fit ARCH model
        model = arch_model(r_log_daily_clipped, vol='Garch', p=p, o=0, q=q)
        model_fit = model.fit()
        
        # Evaluate model using AIC
        aic = model_fit.aic
        
        # Update best parameters if current AIC is lower
        if aic < best_criterion:
            best_p = p
            best_q = q
            best_criterion = aic

print("Best p:", best_p)
print("Best q:", best_q)
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\arch\univariate\base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.291e-07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 1000 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\hp\anaconda3\lib\site-packages\arch\univariate\base.py:766: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# C:\Users\hp\anaconda3\lib\site-packages\arch\univariate\base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.291e-07. Parameter
# ...

# %%
# Clip outliers
lower_bound = r_log_daily.quantile(0.05)
upper_bound = r_log_daily.quantile(0.95)
r_log_daily_clipped = r_log_daily.clip(lower=lower_bound, upper=upper_bound)

# Fit ARCH model with best parameters
model = arch_model(r_log_daily_clipped, vol='Garch', p=1, o=0, q=2)
model_fit = model.fit()

# Display model summary
print(model_fit.summary())
# Out:
# Iteration:      1,   Func. Count:      6,   Neg. LLF: -8070.256064018565
# Inequality constraints incompatible    (Exit mode 4)
#             Current function value: -8070.256064279307
#             Iterations: 1
#             Function evaluations: 6
#             Gradient evaluations: 1
#                      Constant Mean - GARCH Model Results
# ...
# Dep. Variable:              Adj Close   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:                8070.26
# Distribution:                  Normal   AIC:                          -16130.5
# Method:            Maximum Likelihood   BIC:                          -16104.9
#                                         No. Observations:                 1231
# Date:                Sat, Apr 13 2024   Df Residuals:                     1230
# Time:                        15:52:25   Df Model:                            1
# ...

# %%
r_log_daily_rescaled = r_log_daily * 1000

# Fit ARCH model with best parameters
model = arch_model(r_log_daily_rescaled, vol='Garch', p=1, o=0, q=2)
model_fit = model.fit()

# Display model summary
print(model_fit.summary())
# Out:
# Iteration:      1,   Func. Count:      7,   Neg. LLF: 2241933332214.9746
# Iteration:      2,   Func. Count:     18,   Neg. LLF: 3828.7398395743276
# Iteration:      3,   Func. Count:     25,   Neg. LLF: 1718.1662828563674
# Iteration:      4,   Func. Count:     32,   Neg. LLF: 2799.9919545172215
# Iteration:      5,   Func. Count:     39,   Neg. LLF: 1491.0758051478815
# Iteration:      6,   Func. Count:     46,   Neg. LLF: 1484.6480946846034
# Iteration:      7,   Func. Count:     53,   Neg. LLF: 1497.9766876307658
# Iteration:      8,   Func. Count:     60,   Neg. LLF: 1483.4900663017447
# Iteration:      9,   Func. Count:     67,   Neg. LLF: 1483.027979332061
# Iteration:     10,   Func. Count:     74,   Neg. LLF: 1458.4559443799285
# Iteration:     11,   Func. Count:     80,   Neg. LLF: 1457.0422491165339
# Iteration:     12,   Func. Count:     86,   Neg. LLF: 1456.8801172493063
# Iteration:     13,   Func. Count:     92,   Neg. LLF: 1456.8034383798813
# ...

# %%
from arch import arch_model
from sklearn.metrics import mean_squared_error
r_log_daily_clipped = r_log_daily.clip(lower=lower_bound, upper=upper_bound)

# Split the data into training and test sets
train_size = 1000
train_data = r_log_daily_clipped[:train_size]
test_data = r_log_daily_clipped[train_size:]

# Initialize variables to store best model parameters and criterion value
best_p = None
best_q = None
best_rmse = float('inf')  # Initialize with infinity

# Iterate through values of p and q
for p in range(1, 6):
    for q in range(1, 6):
        # Fit ARCH model on training data
        model = arch_model(train_data, vol='Garch', p=p, o=0, q=q)
        model_fit = model.fit()
        
        # Forecast volatility on test data
        forecast_horizon = len(test_data)
        forecast = model_fit.forecast(horizon=forecast_horizon)
        forecast_variance = forecast.variance.values.flatten()
        
        # Calculate root mean squared error (RMSE)
        rmse = np.sqrt(mean_squared_error(test_data, forecast_variance))
        
        # Update best parameters if current RMSE is lower
        if rmse < best_rmse:
            best_p = p
            best_q = q
            best_rmse = rmse

print("Best p:", best_p)
print("Best q:", best_q)
print("Best RMSE:", best_rmse)
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\arch\univariate\base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.428e-07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 1000 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\hp\anaconda3\lib\site-packages\arch\univariate\base.py:766: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# C:\Users\hp\anaconda3\lib\site-packages\arch\univariate\base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.428e-07. Parameter
# ...

# %%
data=r_log_daily_rescaled.clip(lower_bound,upper_bound)

# %%
best_model= arch_model(y=train_data, p=3,q=3).fit(update_freq=5,disp='on')
print(best_model.summary)
# Out:
# <bound method ARCHModelResult.summary of                      Constant Mean - GARCH Model Results
# ...
# Dep. Variable:              Adj Close   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:                6496.20
# Distribution:                  Normal   AIC:                          -12976.4
# Method:            Maximum Likelihood   BIC:                          -12937.1
#                                         No. Observations:                 1000
# Date:                Sat, Apr 13 2024   Df Residuals:                      999
# Time:                        16:06:11   Df Model:                            1
#                                  Mean Model
# ...
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# ...

# %%
# Choose data for Reliance Industries Limited (RELIANCE.NS) for example
reliance_data = combined_data[combined_data['Symbol'] == 'RELIANCE.NS']

# Take the natural logarithm of the adjusted close price
r_log = np.log(reliance_data['Adj Close'])

# Fit ARCH(3) model with adjusted parameters
best_model = arch_model(y=r_log, p=4, q=2, rescale=False).fit(update_freq=5, disp='on')

# Print summary of the best model
print(best_model.summary())
# Out:
#                      Constant Mean - GARCH Model Results
# ...
# Dep. Variable:              Adj Close   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:                227.518
# Distribution:                  Normal   AIC:                          -439.036
# Method:            Maximum Likelihood   BIC:                          -398.098
#                                         No. Observations:                 1233
# Date:                Sat, Apr 13 2024   Df Residuals:                     1232
# Time:                        16:17:27   Df Model:                            1
#                                Mean Model
# ...
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# mu             7.6735  8.679e-03    884.154      0.000 [  7.656,  7.690]
# ...

# %%
# Plot the summary of the best model
best_model.plot()
plt.show()

# %%
import matplotlib.pyplot as plt

# Forecast volatility on the original data
forecast_horizon = len(r_log)
forecast = best_model.forecast(horizon=forecast_horizon)
forecast_variance = forecast.variance.values.flatten()

# Ensure dimensions match by trimming forecasted volatility to match the length of original volatility
forecast_variance_trimmed = forecast_variance[:len(r_log_daily)]

# Plot original volatility vs forecasted volatility
plt.figure(figsize=(10, 6))
plt.plot(r_log_daily.index, r_log_daily, label='Original Volatility', color='blue')
plt.plot(r_log_daily.index, forecast_variance_trimmed, label='Forecasted Volatility', color='red')
plt.title('Original Volatility vs Forecasted Volatility for Reliance Industries Limited (RELIANCE.NS)')
plt.xlabel('Date')
plt.ylabel('Volatility')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
r_log=np.log(reliance_data['Adj Close']).diff().dropna()

# %%
# Calculate rolling variance and add it as a new column
rolling_window = 30  # Adjust the window size as needed
r_log['variance'] = r_log.rolling(window=rolling_window).var()

# Drop rows with missing values (due to the rolling calculation)
r_log.dropna(inplace=True)

# %%
r_log_trimmed = r_log.iloc[29:]

# Print the trimmed DataFrame
print(r_log_trimmed)
# Out:
# 30     -0.021985
# 31     -0.007163
# 32     -0.005272
# 33      0.005559
# 34      0.011880
#           ...
# 1228   -0.000643
# 1229    0.016122
# 1230   -0.009346
# 1231    0.009999
# 1232    0.008430
# Name: Adj Close, Length: 1203, dtype: float64

# %%
import pandas as pd

# Assuming r_log is your DataFrame containing the time series data
# Calculate rolling variance with a window size of 30 (you can adjust this window size as needed)
rolling_variance = r_log.rolling(window=30a).var()

# Drop rows with NaN values, if any
rolling_variance = rolling_variance.dropna()

# Print the rolling variance
print(rolling_variance)
# Out:
# 30      0.000262
# 31      0.000249
# 32      0.000249
# 33      0.000244
# 34      0.000246
#           ...
# 1228    0.000193
# 1229    0.000195
# 1230    0.000196
# 1231    0.000198
# 1232    0.000197
# Name: Adj Close, Length: 1203, dtype: float64

# %%
# Merge r_log_trimmed with the DataFrame containing rolling variance
merged_df = pd.concat([r_log_trimmed, rolling_variance], axis=1)
merged_df.columns = ['Adj Close', 'var']

merged_df = merged_df.reset_index(drop=True)
# Print the merged DataFrame
print(merged_df)
# Out:
#       Adj Close       var
# 0     -0.021985  0.000262
# 1     -0.007163  0.000249
# 2     -0.005272  0.000249
# 3      0.005559  0.000244
# 4      0.011880  0.000246
# ...         ...       ...
# 1198  -0.000643  0.000193
# 1199   0.016122  0.000195
# 1200  -0.009346  0.000196
# 1201   0.009999  0.000198
# 1202   0.008430  0.000197
#
# [1203 rows x 2 columns]

# %%
data=merged_df

# %%
def predict_volatility(x):
    # Fit ARCH model
    best_model = arch_model(y=x['Adj Close'], p=4, q=2).fit(update_freq=5, disp='off')
    
    # Forecast volatility
    forecast = best_model.forecast(horizon=1)
    
    # Extract variance forecast
    variance_forecast = forecast.variance.values[-1][0]
    
    return variance_forecast

# Initialize an empty DataFrame to store predictions
predictions = pd.DataFrame(index=merged_df.index)

# Apply rolling window and predict volatility for each window
for _, window in merged_df.rolling(window=780):
    if len(window) == 30:  # Ensure the window size is 780
        prediction = predict_volatility(window)
        predictions.loc[window.index[-1], 'predictions'] = prediction

# Merge predictions DataFrame with merged_df
merged_df = pd.concat([merged_df, predictions], axis=1)

# Drop NaN values
merged_df.dropna(inplace=True)

# %%
def predict_volatility(x):
    # Fit ARCH model
    best_model = arch_model(y=merged_df.iloc[19]['Adj Close'], p=4, q=2).fit(update_freq=5, disp='off')
    
    # Forecast volatility
    forecast = best_model.forecast(horizon=1)
    
    # Extract variance forecast
    variance_forecast = forecast.variance.values[-1][0]
    print(variance_forecast)
    return variance_forecast

# Initialize an empty list to store predictions
predictions_list = []

# Apply rolling window and predict volatility for each window
for i in range(1203):
    prediction = predict_volatility(i)
    predictions_list.append(prediction)

# Reset index of merged_df
merged_df.reset_index(drop=True, inplace=True)

# Create a DataFrame to store predictions
predictions_df = pd.DataFrame({ 'predictions': predictions_list})

# Drop NaN values from predictions_df
predictions_df.dropna(inplace=True)

# Reset index of predictions_df
predictions_df.reset_index(drop=True, inplace=True)
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\arch\univariate\volatility.py:1197: RuntimeWarning: invalid value encountered in double_scalars
#   scale = np.mean(resids**2) / (target ** (2.0 / power))
# C:\Users\hp\anaconda3\lib\site-packages\arch\univariate\base.py:766: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# C:\Users\hp\anaconda3\lib\site-packages\arch\univariate\volatility.py:1197: RuntimeWarning: invalid value encountered in double_scalars
#   scale = np.mean(resids**2) / (target ** (2.0 / power))
# C:\Users\hp\anaconda3\lib\site-packages\arch\univariate\base.py:766: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# ...

# %%
predictions_df
# Out:
# Empty DataFrame
# Columns: [predictions]
# Index: []

# %%
import pandas as pd
import numpy as np
import arch
import matplotlib.pyplot as plt

# Load the combined stock data from the CSV file
combined_data = pd.read_csv('combined_stock_data.csv')

# Choose data for Reliance Industries Limited (RELIANCE.NS)
reliance_data = combined_data[combined_data['Symbol'] == 'RELIANCE.NS'].copy()  # Make a copy to avoid SettingWithCopyWarning

# Calculate daily returns
reliance_data['Returns'] = reliance_data['Adj Close'].pct_change()

# Drop rows with missing values
reliance_data.dropna(inplace=True)

# Fit a GARCH(1, 1) model to the returns data
model = arch.arch_model(reliance_data['Returns'], mean='Zero', vol='GARCH', p=1, q=1)
results = model.fit()

# Evaluate model performance
aic = results.aic
bic = results.bic
print(f"AIC: {aic}, BIC: {bic}")

# Forecast future volatility
forecast_horizon = 10  # Example: forecast volatility for the next 10 days
forecast = results.forecast(horizon=forecast_horizon)

# Implement risk management and position sizing
threshold = 0.02  # Example: enter position if forecasted volatility exceeds 2%
current_volatility = forecast.mean.iloc[-1]  # Get the last value from the Series
position_size = 10000  # Example: initial position size

# Check if the last value of current_volatility exceeds the threshold
if current_volatility.values[-1] > threshold:
    # Enter long position
    position = position_size
    print("Enter long position")
elif current_volatility.values[-1] < -threshold:
    # Enter short position
    position = -position_size
    print("Enter short position")
else:
    # No trading signal
    position = 0
    print("No trading signal")

# Backtest the trading strategy
reliance_data['Position'] = position
reliance_data['PnL'] = reliance_data['Position'] * reliance_data['Returns']
cumulative_pnl = reliance_data['PnL'].cumsum()

# Visualize the results and performance metrics
plt.figure(figsize=(10, 6))
plt.plot(cumulative_pnl, label='Cumulative P&L')
plt.xlabel('Date')
plt.ylabel('Cumulative P&L')
plt.title('Cumulative Profit and Loss')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\arch\univariate\base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003924. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Iteration:      1,   Func. Count:      5,   Neg. LLF: 689136324.3886477
# Iteration:      2,   Func. Count:     10,   Neg. LLF: -3212.1948570658615
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3212.194856779486
#             Iterations: 6
#             Function evaluations: 10
#             Gradient evaluations: 2
# AIC: -6418.389713558972, BIC: -6403.040531126692
# No trading signal
